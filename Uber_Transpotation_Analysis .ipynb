# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
uber = pd.read_csv("Uber_data.csv")
uber
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
uber.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
uber.describe()
# Out:
#              MILES
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
uber.columns
# Out:
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## Data Cleaning (Handling Missing Values)

# %%
uber.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        0
# CATEGORY        0
# START           0
# STOP            0
# MILES           0
# PURPOSE       502
# dtype: int64

# %%
uber.drop_duplicates()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Data Manipulation ( Filtering Row By COndition)

# %%
filtered_uber = uber[uber["MILES"] > 10]
filtered_uber
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1133   12/29/2016 9:44  12/29/2016 10:07  Business           Kar?chi
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES         PURPOSE
# 4      West Palm Beach   63.7  Customer Visit
# ...

# %%
## Group data calculate statistics 


Average_miles_By_Category = uber.groupby("CATEGORY")["MILES"].mean()
Average_miles_By_Category
# Out:
# CATEGORY
# Business    10.655844
# Personal     9.320779
# Name: MILES, dtype: float64

# %%
## Sorting the Data 

sorted_uber = uber.sort_values(by = "START_DATE")

sorted_uber
# Out:
#           START_DATE         END_DATE  CATEGORY             START  \
# 0     1/1/2016 21:11   1/1/2016 21:17  Business       Fort Pierce
# 9    1/10/2016 12:17  1/10/2016 12:44  Business           Jamaica
# 10   1/10/2016 15:08  1/10/2016 15:51  Business          New York
# 11   1/10/2016 18:18  1/10/2016 18:53  Business          Elmhurst
# 12   1/10/2016 19:12  1/10/2016 19:32  Business           Midtown
# ..               ...              ...       ...               ...
# 778  9/29/2016 16:13  9/29/2016 18:47  Business  Unknown Location
# 779  9/30/2016 17:39  9/30/2016 20:20  Business         Islamabad
# 780  9/30/2016 20:59  9/30/2016 22:34  Business         Islamabad
# 750   9/5/2016 10:25   9/5/2016 10:44  Business  Unknown Location
# 751   9/6/2016 17:49   9/6/2016 17:49  Business  Unknown Location
#
#                  STOP  MILES         PURPOSE
# 0         Fort Pierce    5.1  Meal/Entertain
# 9            New York   16.5  Customer Visit
# ...

# %%
##
uber["PURPOSE"].value_counts().plot.bar()
plt.xlabel("PURPOSE")
plt.ylabel("Count")
plt.title("Count of Trips by Purpose")
plt.show()

# %%
uber["START_DATE"] = pd.to_datetime(uber["START_DATE"])
uber.set_index("START_DATE")["MILES"].plot.line()
plt.ylabel("Miles")
plt.title("Miles  Traveled over Time")
plt.show()

# %%
sns.boxplot( x = 'MILES', y = 'PURPOSE', data=uber)
plt.xlabel("Purpose")
plt.ylabel("Miles")
plt.title("Box Plot : Miles By Purpose")
plt.show()
